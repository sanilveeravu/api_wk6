# %%
# Import the dependencies.

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import requests 

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

import os
import sys

sys.path.insert(1, os.path.join("..","."))

# Get Key for API
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats=np.random.uniform(-90.000,90.000,size=2000)
lngs=np.random.uniform(-180.000,180.000,size=2000)

lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)  
#cities
# Out:
# 811

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
# for i in cities.loc[5,:]:
#     print(cities)
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i].replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    #print(city_url) - Not Logging as it contains key
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | broome
# Processing Record 2 of Set 1 | kuryk
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | bandarbeyla
# Processing Record 6 of Set 1 | pafos
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | fortuna
# Processing Record 11 of Set 1 | narsaq
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | alice springs
# Processing Record 14 of Set 1 | fairbanks
# Processing Record 15 of Set 1 | mushie
# Processing Record 16 of Set 1 | gat
# Processing Record 17 of Set 1 | cibitoke
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | tramore
# Processing Record 24 of Set 1 | nakamura
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | manassas
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | sholapur
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | marienburg
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | presidencia roque saenz pena
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | peno
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | wad madani
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | honiara
# Processing Record 46 of Set 1 | antofagasta
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | beringovskiy
# Processing Record 49 of Set 1 | iisaku
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | eureka
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | bud
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | paamiut
# Processing Record 9 of Set 2 | twin falls
# Processing Record 10 of Set 2 | luena
# Processing Record 11 of Set 2 | mayo
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | sudbury
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | stephenville
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | lujan
# Processing Record 21 of Set 2 | coruripe
# Processing Record 22 of Set 2 | zverinogolovskoye
# Processing Record 23 of Set 2 | dilla
# Processing Record 24 of Set 2 | yeppoon
# Processing Record 25 of Set 2 | moyale
# Processing Record 26 of Set 2 | zhigansk
# Processing Record 27 of Set 2 | butembo
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | santa cruz de tenerife
# Processing Record 30 of Set 2 | gondar
# Processing Record 31 of Set 2 | yerbogachen
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | olafsvik
# Processing Record 34 of Set 2 | santiago de cao
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 2 | tambul
# City not found. Skipping...
# Processing Record 38 of Set 2 | guiyang
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | talara
# Processing Record 42 of Set 2 | svetlogorsk
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | alyangula
# Processing Record 45 of Set 2 | lhokseumawe
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | rikitea
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | wazzan
# City not found. Skipping...
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | okhtyrka
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | xining
# Processing Record 6 of Set 3 | zuhres
# Processing Record 7 of Set 3 | huarmey
# Processing Record 8 of Set 3 | tvoroyri
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | duku
# Processing Record 11 of Set 3 | surt
# Processing Record 12 of Set 3 | huilong
# Processing Record 13 of Set 3 | cap malheureux
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | catamarca
# Processing Record 17 of Set 3 | kavarna
# Processing Record 18 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 3 | bambanglipuro
# Processing Record 20 of Set 3 | baykalovo
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | bondo
# Processing Record 24 of Set 3 | chumikan
# Processing Record 25 of Set 3 | kapuskasing
# Processing Record 26 of Set 3 | kontagora
# Processing Record 27 of Set 3 | brae
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | sobolevo
# Processing Record 30 of Set 3 | la serena
# Processing Record 31 of Set 3 | weener
# Processing Record 32 of Set 3 | lashio
# Processing Record 33 of Set 3 | nioro
# Processing Record 34 of Set 3 | stekolnyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | porto santo
# Processing Record 38 of Set 3 | tual
# Processing Record 39 of Set 3 | bensonville
# Processing Record 40 of Set 3 | oktyabrskiy
# Processing Record 41 of Set 3 | muros
# Processing Record 42 of Set 3 | suntar
# Processing Record 43 of Set 3 | san jorge
# Processing Record 44 of Set 3 | hofn
# Processing Record 45 of Set 3 | saint-joseph
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | kawalu
# Processing Record 49 of Set 3 | teluk nibung
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | igarka
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 7 of Set 4 | bathsheba
# Processing Record 8 of Set 4 | yankton
# Processing Record 9 of Set 4 | shingu
# Processing Record 10 of Set 4 | karratha
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | summerside
# Processing Record 13 of Set 4 | kloulklubed
# Processing Record 14 of Set 4 | gold coast
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | melville
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | waitara
# Processing Record 19 of Set 4 | praia da vitoria
# Processing Record 20 of Set 4 | mount isa
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | celestun
# Processing Record 23 of Set 4 | dingle
# Processing Record 24 of Set 4 | urumqi
# Processing Record 25 of Set 4 | tommot
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | kavaratti
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | jiuquan
# Processing Record 30 of Set 4 | ayagoz
# Processing Record 31 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 4 | sorland
# Processing Record 33 of Set 4 | sumbe
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | nuuk
# Processing Record 37 of Set 4 | san miguel
# Processing Record 38 of Set 4 | pojorata
# Processing Record 39 of Set 4 | mizan teferi
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | blythe
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | ilulissat
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | changqing
# Processing Record 47 of Set 4 | cayenne
# Processing Record 48 of Set 4 | san policarpo
# Processing Record 49 of Set 4 | nhamunda
# Processing Record 50 of Set 4 | ewa beach
# Processing Record 1 of Set 5 | sioux lookout
# Processing Record 2 of Set 5 | kolokani
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | leningradskiy
# Processing Record 5 of Set 5 | okhotsk
# Processing Record 6 of Set 5 | nome
# Processing Record 7 of Set 5 | maragogi
# Processing Record 8 of Set 5 | krasnokholm
# Processing Record 9 of Set 5 | invermere
# Processing Record 10 of Set 5 | port macquarie
# Processing Record 11 of Set 5 | mantua
# Processing Record 12 of Set 5 | souillac
# Processing Record 13 of Set 5 | buraydah
# Processing Record 14 of Set 5 | northam
# Processing Record 15 of Set 5 | pushkar
# Processing Record 16 of Set 5 | bilbor
# Processing Record 17 of Set 5 | werda
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | rocha
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | cape canaveral
# Processing Record 22 of Set 5 | puerto ayora
# Processing Record 23 of Set 5 | huicungo
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | jacareacanga
# Processing Record 27 of Set 5 | ahipara
# Processing Record 28 of Set 5 | vostok
# Processing Record 29 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | nemuro
# Processing Record 32 of Set 5 | agirish
# Processing Record 33 of Set 5 | auki
# Processing Record 34 of Set 5 | muzquiz
# City not found. Skipping...
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | tres barras
# Processing Record 37 of Set 5 | perbaungan
# Processing Record 38 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 5 | parrita
# Processing Record 40 of Set 5 | caravelas
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | lata
# Processing Record 43 of Set 5 | yuncheng
# Processing Record 44 of Set 5 | nouakchott
# Processing Record 45 of Set 5 | lukovetskiy
# Processing Record 46 of Set 5 | ilebo
# Processing Record 47 of Set 5 | victoria
# Processing Record 48 of Set 5 | jerome
# Processing Record 49 of Set 5 | camacha
# Processing Record 50 of Set 5 | te anau
# Processing Record 1 of Set 6 | khandyga
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | greenwood
# Processing Record 4 of Set 6 | kysyl-syr
# Processing Record 5 of Set 6 | ipixuna
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | akhmeta
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | westport
# Processing Record 10 of Set 6 | georgetown
# Processing Record 11 of Set 6 | yatou
# Processing Record 12 of Set 6 | masaurhi
# Processing Record 13 of Set 6 | skibotn
# Processing Record 14 of Set 6 | dhangadhi
# Processing Record 15 of Set 6 | vardo
# Processing Record 16 of Set 6 | qaqortoq
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | romitan
# Processing Record 19 of Set 6 | tura
# Processing Record 20 of Set 6 | sibay
# Processing Record 21 of Set 6 | ixtapa
# Processing Record 22 of Set 6 | zyryanovsk
# Processing Record 23 of Set 6 | cedar hill
# Processing Record 24 of Set 6 | saint-augustin
# Processing Record 25 of Set 6 | bolitoc
# Processing Record 26 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 6 | vaasa
# Processing Record 28 of Set 6 | camana
# Processing Record 29 of Set 6 | elmira
# Processing Record 30 of Set 6 | darnah
# Processing Record 31 of Set 6 | albanel
# Processing Record 32 of Set 6 | bilibino
# Processing Record 33 of Set 6 | port-gentil
# Processing Record 34 of Set 6 | mackay
# Processing Record 35 of Set 6 | sterling
# Processing Record 36 of Set 6 | malazgirt
# Processing Record 37 of Set 6 | nikolskoye
# Processing Record 38 of Set 6 | cascais
# Processing Record 39 of Set 6 | boa vista
# Processing Record 40 of Set 6 | hithadhoo
# Processing Record 41 of Set 6 | dawson creek
# Processing Record 42 of Set 6 | laguna
# Processing Record 43 of Set 6 | kiunga
# Processing Record 44 of Set 6 | paungde
# Processing Record 45 of Set 6 | coihaique
# Processing Record 46 of Set 6 | belle fourche
# Processing Record 47 of Set 6 | san ignacio
# Processing Record 48 of Set 6 | torbay
# Processing Record 49 of Set 6 | muskegon
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | maarianhamina
# Processing Record 2 of Set 7 | lubango
# Processing Record 3 of Set 7 | burica
# City not found. Skipping...
# Processing Record 4 of Set 7 | rockhampton
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | gwadar
# Processing Record 7 of Set 7 | qostanay
# Processing Record 8 of Set 7 | birkeland
# Processing Record 9 of Set 7 | babstovo
# Processing Record 10 of Set 7 | da lat
# Processing Record 11 of Set 7 | touros
# Processing Record 12 of Set 7 | gaimersheim
# Processing Record 13 of Set 7 | asau
# Processing Record 14 of Set 7 | gravelbourg
# Processing Record 15 of Set 7 | placido de castro
# Processing Record 16 of Set 7 | dunn
# Processing Record 17 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 7 | goya
# Processing Record 19 of Set 7 | half moon bay
# Processing Record 20 of Set 7 | haines junction
# Processing Record 21 of Set 7 | ampanihy
# Processing Record 22 of Set 7 | orlik
# Processing Record 23 of Set 7 | tugulym
# Processing Record 24 of Set 7 | vrangel
# Processing Record 25 of Set 7 | kushima
# Processing Record 26 of Set 7 | aketi
# Processing Record 27 of Set 7 | port keats
# Processing Record 28 of Set 7 | ardesen
# Processing Record 29 of Set 7 | puli
# Processing Record 30 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 7 | halifax
# Processing Record 32 of Set 7 | isangel
# Processing Record 33 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 7 | ribeira grande
# Processing Record 35 of Set 7 | yenagoa
# Processing Record 36 of Set 7 | richards bay
# Processing Record 37 of Set 7 | vila velha
# Processing Record 38 of Set 7 | naze
# Processing Record 39 of Set 7 | los llanos de aridane
# Processing Record 40 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 7 | chesma
# Processing Record 42 of Set 7 | fukue
# Processing Record 43 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | kotri
# Processing Record 45 of Set 7 | mirnyy
# Processing Record 46 of Set 7 | honningsvag
# Processing Record 47 of Set 7 | maniitsoq
# Processing Record 48 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 7 | kodinsk
# Processing Record 50 of Set 7 | cockburn town
# Processing Record 1 of Set 8 | geraldton
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | zhireken
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | mokhsogollokh
# Processing Record 7 of Set 8 | desaguadero
# Processing Record 8 of Set 8 | beira
# Processing Record 9 of Set 8 | joensuu
# Processing Record 10 of Set 8 | guayanilla
# Processing Record 11 of Set 8 | provideniya
# Processing Record 12 of Set 8 | abashiri
# Processing Record 13 of Set 8 | gudari
# Processing Record 14 of Set 8 | tigre
# Processing Record 15 of Set 8 | grabouw
# Processing Record 16 of Set 8 | umm lajj
# Processing Record 17 of Set 8 | homer
# Processing Record 18 of Set 8 | pemangkat
# Processing Record 19 of Set 8 | yumen
# Processing Record 20 of Set 8 | port lincoln
# Processing Record 21 of Set 8 | qasigiannguit
# Processing Record 22 of Set 8 | sirfa
# City not found. Skipping...
# Processing Record 23 of Set 8 | san isidro
# Processing Record 24 of Set 8 | capao da canoa
# Processing Record 25 of Set 8 | rajshahi
# Processing Record 26 of Set 8 | jalu
# Processing Record 27 of Set 8 | asahi
# Processing Record 28 of Set 8 | price
# Processing Record 29 of Set 8 | les cayes
# Processing Record 30 of Set 8 | flin flon
# Processing Record 31 of Set 8 | rio gallegos
# Processing Record 32 of Set 8 | itaituba
# Processing Record 33 of Set 8 | zarinsk
# Processing Record 34 of Set 8 | liverpool
# Processing Record 35 of Set 8 | flic en flac
# Processing Record 36 of Set 8 | nago
# Processing Record 37 of Set 8 | sao francisco
# Processing Record 38 of Set 8 | oskemen
# Processing Record 39 of Set 8 | belyy yar
# Processing Record 40 of Set 8 | manokwari
# Processing Record 41 of Set 8 | belaya gora
# Processing Record 42 of Set 8 | adolfo lopez mateos
# Processing Record 43 of Set 8 | alibag
# Processing Record 44 of Set 8 | komatsu
# Processing Record 45 of Set 8 | cam ranh
# Processing Record 46 of Set 8 | sorong
# Processing Record 47 of Set 8 | kundiawa
# Processing Record 48 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 8 | goure
# Processing Record 50 of Set 8 | ulladulla
# Processing Record 1 of Set 9 | ust-maya
# Processing Record 2 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 9 | batie
# Processing Record 4 of Set 9 | dundalk
# Processing Record 5 of Set 9 | chynov
# Processing Record 6 of Set 9 | la asuncion
# Processing Record 7 of Set 9 | sola
# Processing Record 8 of Set 9 | cabedelo
# Processing Record 9 of Set 9 | riyadh
# Processing Record 10 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 11 of Set 9 | kurchum
# Processing Record 12 of Set 9 | turukhansk
# Processing Record 13 of Set 9 | broken hill
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | lagoa
# Processing Record 16 of Set 9 | oltu
# Processing Record 17 of Set 9 | namie
# Processing Record 18 of Set 9 | shurugwi
# Processing Record 19 of Set 9 | charagua
# Processing Record 20 of Set 9 | lethem
# Processing Record 21 of Set 9 | tuy hoa
# Processing Record 22 of Set 9 | yulara
# Processing Record 23 of Set 9 | buala
# Processing Record 24 of Set 9 | metu
# Processing Record 25 of Set 9 | sabinas
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | katsuura
# Processing Record 28 of Set 9 | igrim
# Processing Record 29 of Set 9 | honghu
# Processing Record 30 of Set 9 | escanaba
# Processing Record 31 of Set 9 | bubaque
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | tromso
# Processing Record 34 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 9 | guanambi
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | saint-pascal
# City not found. Skipping...
# Processing Record 38 of Set 9 | acolla
# Processing Record 39 of Set 9 | hede
# Processing Record 40 of Set 9 | grindavik
# Processing Record 41 of Set 9 | baijiantan
# Processing Record 42 of Set 9 | gaoual
# Processing Record 43 of Set 9 | vestmannaeyjar
# Processing Record 44 of Set 9 | imaculada
# Processing Record 45 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 9 | tarbagatay
# Processing Record 48 of Set 9 | samarai
# Processing Record 49 of Set 9 | boyuibe
# Processing Record 50 of Set 9 | cabo san lucas
# Processing Record 1 of Set 10 | shush
# Processing Record 2 of Set 10 | hovd
# Processing Record 3 of Set 10 | ponta delgada
# Processing Record 4 of Set 10 | semnan
# Processing Record 5 of Set 10 | pali
# Processing Record 6 of Set 10 | pires do rio
# Processing Record 7 of Set 10 | fort nelson
# Processing Record 8 of Set 10 | aleksandrov gay
# Processing Record 9 of Set 10 | kalmunai
# Processing Record 10 of Set 10 | peringat
# Processing Record 11 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 10 | lourdes
# Processing Record 13 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 10 | puerto narino
# Processing Record 15 of Set 10 | luanda
# Processing Record 16 of Set 10 | jiblah
# Processing Record 17 of Set 10 | starobaltachevo
# Processing Record 18 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 19 of Set 10 | wanlaweyn
# Processing Record 20 of Set 10 | teguise
# Processing Record 21 of Set 10 | barcelos
# Processing Record 22 of Set 10 | chernyshevskiy
# Processing Record 23 of Set 10 | wajima
# Processing Record 24 of Set 10 | vao
# Processing Record 25 of Set 10 | rawa mazowiecka
# Processing Record 26 of Set 10 | sandakan
# Processing Record 27 of Set 10 | mana
# Processing Record 28 of Set 10 | grimshaw
# Processing Record 29 of Set 10 | ploemeur
# Processing Record 30 of Set 10 | podgornoye
# Processing Record 31 of Set 10 | luganville
# Processing Record 32 of Set 10 | clyde river
# Processing Record 33 of Set 10 | lulea
# Processing Record 34 of Set 10 | copiapo
# Processing Record 35 of Set 10 | adre
# Processing Record 36 of Set 10 | solnechnyy
# Processing Record 37 of Set 10 | margate
# Processing Record 38 of Set 10 | buchanan
# Processing Record 39 of Set 10 | poselki
# Processing Record 40 of Set 10 | quatre cocos
# Processing Record 41 of Set 10 | ancud
# Processing Record 42 of Set 10 | techiman
# Processing Record 43 of Set 10 | ukiah
# Processing Record 44 of Set 10 | nouadhibou
# Processing Record 45 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 10 | minbu
# Processing Record 47 of Set 10 | nileshwar
# Processing Record 48 of Set 10 | uruzgan
# Processing Record 49 of Set 10 | las vegas
# Processing Record 50 of Set 10 | jutai
# Processing Record 1 of Set 11 | coahuayana
# Processing Record 2 of Set 11 | monte patria
# Processing Record 3 of Set 11 | santiago
# Processing Record 4 of Set 11 | kasongo
# Processing Record 5 of Set 11 | qandala
# Processing Record 6 of Set 11 | joshimath
# Processing Record 7 of Set 11 | tecoanapa
# Processing Record 8 of Set 11 | kungurtug
# Processing Record 9 of Set 11 | calvinia
# Processing Record 10 of Set 11 | verkhnyaya toyma
# Processing Record 11 of Set 11 | roma
# Processing Record 12 of Set 11 | poum
# Processing Record 13 of Set 11 | matara
# Processing Record 14 of Set 11 | emerald
# Processing Record 15 of Set 11 | kutum
# Processing Record 16 of Set 11 | spanish fork
# Processing Record 17 of Set 11 | fare
# Processing Record 18 of Set 11 | paracuru
# Processing Record 19 of Set 11 | bone
# Processing Record 20 of Set 11 | iqaluit
# Processing Record 21 of Set 11 | basco
# Processing Record 22 of Set 11 | pryozerne
# Processing Record 23 of Set 11 | yuzhne
# Processing Record 24 of Set 11 | mercedes
# Processing Record 25 of Set 11 | kijang
# Processing Record 26 of Set 11 | chaumont
# Processing Record 27 of Set 11 | tacuati
# Processing Record 28 of Set 11 | dukat
# Processing Record 29 of Set 11 | antalaha
# Processing Record 30 of Set 11 | north bend
# Processing Record 31 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 11 | bastrop
# Processing Record 33 of Set 11 | nenjiang
# Processing Record 34 of Set 11 | serebryanyy bor
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | evensk
# Processing Record 37 of Set 11 | bandrele
# Processing Record 38 of Set 11 | sao joao da barra
# Processing Record 39 of Set 11 | oriximina
# Processing Record 40 of Set 11 | susanville
# Processing Record 41 of Set 11 | zykovo
# Processing Record 42 of Set 11 | anadyr
# Processing Record 43 of Set 11 | ornskoldsvik
# Processing Record 44 of Set 11 | kupang
# Processing Record 45 of Set 11 | kenai
# Processing Record 46 of Set 11 | singapore
# Processing Record 47 of Set 11 | vanimo
# Processing Record 48 of Set 11 | sevierville
# Processing Record 49 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 11 | saint-georges
# Processing Record 1 of Set 12 | lingao
# Processing Record 2 of Set 12 | pokhara
# Processing Record 3 of Set 12 | deputatskiy
# Processing Record 4 of Set 12 | iskateley
# Processing Record 5 of Set 12 | west bay
# Processing Record 6 of Set 12 | jonesboro
# Processing Record 7 of Set 12 | amazar
# Processing Record 8 of Set 12 | san jose
# Processing Record 9 of Set 12 | mayskiy
# Processing Record 10 of Set 12 | methoni
# Processing Record 11 of Set 12 | ulkan
# Processing Record 12 of Set 12 | ouesso
# Processing Record 13 of Set 12 | krasnyy chikoy
# Processing Record 14 of Set 12 | sao jose da coroa grande
# Processing Record 15 of Set 12 | araouane
# Processing Record 16 of Set 12 | benalla
# Processing Record 17 of Set 12 | healdsburg
# Processing Record 18 of Set 12 | hami
# Processing Record 19 of Set 12 | santa isabel
# Processing Record 20 of Set 12 | sakakah
# Processing Record 21 of Set 12 | codrington
# Processing Record 22 of Set 12 | belmonte
# Processing Record 23 of Set 12 | saskatoon
# Processing Record 24 of Set 12 | mbour
# Processing Record 25 of Set 12 | abbeville
# Processing Record 26 of Set 12 | padang
# Processing Record 27 of Set 12 | villazon
# Processing Record 28 of Set 12 | kokopo
# Processing Record 29 of Set 12 | guiglo
# Processing Record 30 of Set 12 | la ronge
# Processing Record 31 of Set 12 | soe
# Processing Record 32 of Set 12 | rognan
# Processing Record 33 of Set 12 | yartsevo
# Processing Record 34 of Set 12 | ingham
# Processing Record 35 of Set 12 | zhongxing
# Processing Record 36 of Set 12 | shaoguan
# Processing Record 37 of Set 12 | dunedin
# Processing Record 38 of Set 12 | sarny
# Processing Record 39 of Set 12 | vila franca do campo
# Processing Record 40 of Set 12 | ahuimanu
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | banyo
# Processing Record 43 of Set 12 | palu
# Processing Record 44 of Set 12 | linguere
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | tilichiki
# Processing Record 47 of Set 12 | mandalgovi
# Processing Record 48 of Set 12 | labrea
# Processing Record 49 of Set 12 | mahendragarh
# Processing Record 50 of Set 12 | vargashi
# Processing Record 1 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 13 | bella vista
# Processing Record 3 of Set 13 | yanji
# Processing Record 4 of Set 13 | carbonia
# Processing Record 5 of Set 13 | alamos
# Processing Record 6 of Set 13 | kolno
# Processing Record 7 of Set 13 | mirabela
# Processing Record 8 of Set 13 | grootfontein
# Processing Record 9 of Set 13 | jimenez
# Processing Record 10 of Set 13 | garoua boulai
# Processing Record 11 of Set 13 | aquidauana
# Processing Record 12 of Set 13 | santa catarina de tepehuanes
# Processing Record 13 of Set 13 | billings
# Processing Record 14 of Set 13 | itabira
# Processing Record 15 of Set 13 | muroto
# Processing Record 16 of Set 13 | mbandaka
# Processing Record 17 of Set 13 | ojinaga
# Processing Record 18 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 19 of Set 13 | lakes entrance
# Processing Record 20 of Set 13 | nakodar
# Processing Record 21 of Set 13 | pingliang
# Processing Record 22 of Set 13 | bekwai
# Processing Record 23 of Set 13 | college
# Processing Record 24 of Set 13 | rolla
# Processing Record 25 of Set 13 | viedma
# Processing Record 26 of Set 13 | marawi
# Processing Record 27 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 28 of Set 13 | vodnyy
# Processing Record 29 of Set 13 | cap-aux-meules
# Processing Record 30 of Set 13 | inuvik
# Processing Record 31 of Set 13 | otradnoye
# Processing Record 32 of Set 13 | boyolangu
# Processing Record 33 of Set 13 | nalut
# Processing Record 34 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 13 | kollam
# Processing Record 37 of Set 13 | skjervoy
# Processing Record 38 of Set 13 | eyl
# Processing Record 39 of Set 13 | porto novo
# Processing Record 40 of Set 13 | bryan
# Processing Record 41 of Set 13 | beipiao
# Processing Record 42 of Set 13 | hare bay
# Processing Record 43 of Set 13 | lanzhou
# Processing Record 44 of Set 13 | balkhash
# Processing Record 45 of Set 13 | cozumel
# Processing Record 46 of Set 13 | assinovskaya
# Processing Record 47 of Set 13 | epinal
# Processing Record 48 of Set 13 | pimenta bueno
# Processing Record 49 of Set 13 | merritt island
# Processing Record 50 of Set 13 | genhe
# Processing Record 1 of Set 14 | benin
# Processing Record 2 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 14 | puerto santander
# Processing Record 4 of Set 14 | itoman
# Processing Record 5 of Set 14 | aswan
# Processing Record 6 of Set 14 | thinadhoo
# Processing Record 7 of Set 14 | bilma
# Processing Record 8 of Set 14 | isla mujeres
# Processing Record 9 of Set 14 | doha
# Processing Record 10 of Set 14 | dillon
# Processing Record 11 of Set 14 | fort-shevchenko
# Processing Record 12 of Set 14 | itarema
# Processing Record 13 of Set 14 | high level
# Processing Record 14 of Set 14 | central point
# Processing Record 15 of Set 14 | filadelfia
# Processing Record 16 of Set 14 | ferme-neuve
# Processing Record 17 of Set 14 | mae hong son
# Processing Record 18 of Set 14 | wanning
# Processing Record 19 of Set 14 | natal
# Processing Record 20 of Set 14 | port blair
# Processing Record 21 of Set 14 | saint anthony
# Processing Record 22 of Set 14 | yar-sale
# Processing Record 23 of Set 14 | kotelnich
# Processing Record 24 of Set 14 | kushiro
# Processing Record 25 of Set 14 | batagay-alyta
# Processing Record 26 of Set 14 | chapais
# Processing Record 27 of Set 14 | gizo
# Processing Record 28 of Set 14 | vallenar
# Processing Record 29 of Set 14 | nishihara
# Processing Record 30 of Set 14 | sinop
# Processing Record 31 of Set 14 | farmington
# Processing Record 32 of Set 14 | kiama
# Processing Record 33 of Set 14 | sinnamary
# Processing Record 34 of Set 14 | mehamn
# Processing Record 35 of Set 14 | upernavik
# Processing Record 36 of Set 14 | zamania
# Processing Record 37 of Set 14 | makakilo city
# Processing Record 38 of Set 14 | porto recanati
# Processing Record 39 of Set 14 | conchas
# Processing Record 40 of Set 14 | gra liyia
# Processing Record 41 of Set 14 | marrakesh
# Processing Record 42 of Set 14 | vesoul
# Processing Record 43 of Set 14 | barra
# Processing Record 44 of Set 14 | loa janan
# Processing Record 45 of Set 14 | tingo maria
# Processing Record 46 of Set 14 | arlit
# Processing Record 47 of Set 14 | korla
# Processing Record 48 of Set 14 | ovalle
# Processing Record 49 of Set 14 | nantucket
# Processing Record 50 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 15 | henties bay
# Processing Record 2 of Set 15 | goderich
# Processing Record 3 of Set 15 | charters towers
# Processing Record 4 of Set 15 | necochea
# Processing Record 5 of Set 15 | loudeac
# Processing Record 6 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 15 | saint-francois
# Processing Record 8 of Set 15 | kyzyl-suu
# Processing Record 9 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 15 | nicolas bravo
# Processing Record 11 of Set 15 | palembang
# Processing Record 12 of Set 15 | xuddur
# Processing Record 13 of Set 15 | dudinka
# Processing Record 14 of Set 15 | blairmore
# Processing Record 15 of Set 15 | vastervik
# City not found. Skipping...
# Processing Record 16 of Set 15 | awbari
# Processing Record 17 of Set 15 | birao
# Processing Record 18 of Set 15 | anchorage
# Processing Record 19 of Set 15 | matay
# Processing Record 20 of Set 15 | brokopondo
# Processing Record 21 of Set 15 | lucea
# Processing Record 22 of Set 15 | hammerfest
# Processing Record 23 of Set 15 | nisia floresta
# Processing Record 24 of Set 15 | ambunti
# Processing Record 25 of Set 15 | jieshi
# Processing Record 26 of Set 15 | boyabat
# Processing Record 27 of Set 15 | vestmanna
# Processing Record 28 of Set 15 | diego de almagro
# Processing Record 29 of Set 15 | phonhong
# Processing Record 30 of Set 15 | shelburne
# Processing Record 31 of Set 15 | qui nhon
# Processing Record 32 of Set 15 | sabha
# Processing Record 33 of Set 15 | meulaboh
# Processing Record 34 of Set 15 | batemans bay
# Processing Record 35 of Set 15 | burns lake
# Processing Record 36 of Set 15 | zatoka
# Processing Record 37 of Set 15 | poopo
# Processing Record 38 of Set 15 | villarrica
# Processing Record 39 of Set 15 | takaka
# Processing Record 40 of Set 15 | monastyrshchina
# Processing Record 41 of Set 15 | novyy urengoy
# Processing Record 42 of Set 15 | koshurnikovo
# Processing Record 43 of Set 15 | rawson
# Processing Record 44 of Set 15 | kuusamo
# Processing Record 45 of Set 15 | liku
# Processing Record 46 of Set 15 | sandpoint
# Processing Record 47 of Set 15 | yambio
# Processing Record 48 of Set 15 | kotido
# Processing Record 49 of Set 15 | winnipeg
# Processing Record 50 of Set 15 | grand gaube
# Processing Record 1 of Set 16 | west fargo
# Processing Record 2 of Set 16 | zdvinsk
# Processing Record 3 of Set 16 | marv dasht
# City not found. Skipping...
# Processing Record 4 of Set 16 | amga
# Processing Record 5 of Set 16 | ziro
# Processing Record 6 of Set 16 | hailar
# Processing Record 7 of Set 16 | ambilobe
# Processing Record 8 of Set 16 | bundu
# Processing Record 9 of Set 16 | kirakira
# Processing Record 10 of Set 16 | mahuva
# Processing Record 11 of Set 16 | utete
# Processing Record 12 of Set 16 | lubao
# Processing Record 13 of Set 16 | gilbues
# Processing Record 14 of Set 16 | mizdah
# Processing Record 15 of Set 16 | kalaleh
# Processing Record 16 of Set 16 | dabakala
# Processing Record 17 of Set 16 | murici
# Processing Record 18 of Set 16 | kaeo
# Processing Record 19 of Set 16 | hohhot
# Processing Record 20 of Set 16 | nesna
# Processing Record 21 of Set 16 | asuncion nochixtlan
# Processing Record 22 of Set 16 | lompoc
# Processing Record 23 of Set 16 | takoradi
# Processing Record 24 of Set 16 | jardim
# Processing Record 25 of Set 16 | simao
# Processing Record 26 of Set 16 | chingirlau
# Processing Record 27 of Set 16 | chake chake
# Processing Record 28 of Set 16 | kasongo-lunda
# Processing Record 29 of Set 16 | teguldet
# Processing Record 30 of Set 16 | algeciras
# Processing Record 31 of Set 16 | myitkyina
# Processing Record 32 of Set 16 | ust-kuyga
# Processing Record 33 of Set 16 | namuac
# Processing Record 34 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 16 | dargaville
# Processing Record 36 of Set 16 | komsomolskoye
# Processing Record 37 of Set 16 | andilamena
# Processing Record 38 of Set 16 | sembe
# Processing Record 39 of Set 16 | kangavar
# Processing Record 40 of Set 16 | manzil salim
# Processing Record 41 of Set 16 | sosnovo-ozerskoye
# Processing Record 42 of Set 16 | waingapu
# Processing Record 43 of Set 16 | waipawa
# Processing Record 44 of Set 16 | bat yam
# Processing Record 45 of Set 16 | bataipora
# Processing Record 46 of Set 16 | kurilsk
# Processing Record 47 of Set 16 | ust-nera
# Processing Record 48 of Set 16 | kibaya
# Processing Record 49 of Set 16 | tharrawaddy
# City not found. Skipping...
# Processing Record 50 of Set 16 | mitsamiouli
# Processing Record 1 of Set 17 | smithers
# Processing Record 2 of Set 17 | kyrksaeterora
# Processing Record 3 of Set 17 | la plata
# Processing Record 4 of Set 17 | wilmington island
# Processing Record 5 of Set 17 | churapcha
# Processing Record 6 of Set 17 | hokitika
# Processing Record 7 of Set 17 | amahai
# Processing Record 8 of Set 17 | henzada
# City not found. Skipping...
# Processing Record 9 of Set 17 | tucuman
# Processing Record 10 of Set 17 | tamandare
# Processing Record 11 of Set 17 | puruaran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Broome      US  42.2506  -75.8330     70.02        28           0
# 1         Kuryk      KZ  43.2000   51.6500     68.29        46           6
# 2        Atuona      PF  -9.8000 -139.0333     78.89        77          65
# 3     Busselton      AU -33.6500  115.3333     57.20        84           9
# 4   Bandarbeyla      SO   9.4942   50.8122     84.47        76          64
# 5         Pafos      CY  34.7667   32.4167     65.98        82          20
# 6  Punta Arenas      CL -53.1500  -70.9167     48.11        87          78
# 7      Hermanus      ZA -34.4187   19.2345     61.81        85           0
# 8   New Norfolk      AU -42.7826  147.0587     60.30        84          97
# 9       Fortuna      US  40.5982 -124.1573     58.93        77          75
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1       18.66           clear sky
# 2       13.65       broken clouds
# 3        2.64           clear sky
# 4       10.42       broken clouds
# 5        9.22          few clouds
# 6        5.28       broken clouds
# 7       10.16           clear sky
# 8        1.01     overcast clouds
# 9       11.50       broken clouds

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 752 entries, 0 to 751
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 752 non-null    object
#  1   Country              752 non-null    object
#  2   Lat                  752 non-null    float64
#  3   Lng                  752 non-null    float64
#  4   Max Temp             752 non-null    float64
#  5   Humidity             752 non-null    int64
#  6   Cloudiness           752 non-null    int64
#  7   Wind Speed           752 non-null    float64
#  8   Current Description  752 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 53.0+ KB

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Broome      US  42.2506  -75.8330     70.02        28           0
# 1         Kuryk      KZ  43.2000   51.6500     68.29        46           6
# 2        Atuona      PF  -9.8000 -139.0333     78.89        77          65
# 3     Busselton      AU -33.6500  115.3333     57.20        84           9
# 4   Bandarbeyla      SO   9.4942   50.8122     84.47        76          64
# 5         Pafos      CY  34.7667   32.4167     65.98        82          20
# 6  Punta Arenas      CL -53.1500  -70.9167     48.11        87          78
# 7      Hermanus      ZA -34.4187   19.2345     61.81        85           0
# 8   New Norfolk      AU -42.7826  147.0587     60.30        84          97
# 9       Fortuna      US  40.5982 -124.1573     58.93        77          75
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1       18.66           clear sky
# 2       13.65       broken clouds
# 3        2.64           clear sky
# 4       10.42       broken clouds
# 5        9.22          few clouds
# 6        5.28       broken clouds
# 7       10.16           clear sky
# 8        1.01     overcast clouds
# 9       11.50       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
